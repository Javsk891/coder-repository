# %% [markdown]
# <a href="https://colab.research.google.com/github/Javsk891/coder-repository/blob/main/Hearth_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/05393-heart_failure_clinical_records_dataset.csv', ';', on_bad_lines='skip')   # Cargamos el Archivo ejemplo proporcionado por el tutor
df  # Visualizamos el DataFrame df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# ...

# %%
df.columns  # Visualizamos las columnas del dataset df
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
len(df.columns)  # Obtenemos el número exacto de columnas del dataset df
# Out:
# 13

# %% [markdown]
# Primer Dataset propuesto para el proyecto final (Los datasets que he tratado de buscar, tienen que ver con tematicas ambientales, en este caso con las poblaciones de abejas y sus afectaciones por el uso de agroquímicos

# %%
df1 = pd.read_csv('/content/vHoneyNeonic_v02.csv')  # Cargamos el primer dataset que podría ser utlizado para el proyecto final 
df1   # Visualizamos el dataframe df1
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0      AL  11000.0           56   616000.0  209000.0        1.49   918000.0
# 1      AL  11000.0           72   792000.0  230000.0        1.21   958000.0
# 2      AL  12000.0           86  1032000.0  103000.0        1.18  1218000.0
# 3      AL  12000.0           87  1044000.0  282000.0        1.41  1472000.0
# 4      AL  13000.0           66   858000.0  266000.0        1.02   875000.0
# ..    ...      ...          ...        ...       ...         ...        ...
# 820    WY  40000.0           68  2720000.0  190000.0        1.78  4842000.0
# 821    WY  43000.0           80  3440000.0  894000.0        1.00  3440000.0
# 822    WY  46000.0           60  2760000.0  524000.0        0.68  1877000.0
# 823    WY  47000.0           66  3102000.0  558000.0        2.11  6545000.0
# 824    WY  50000.0           51  2550000.0  459000.0        1.87  4769000.0
#
# ...

# %%
df1.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year', 'StateName', 'Region', 'nCLOTHIANIDIN',
#        'nIMIDACLOPRID', 'nTHIAMETHOXAM', 'nACETAMIPRID', 'nTHIACLOPRID',
#        'nAllNeonic'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 13

# %% [markdown]
# Segundo Dataset propuesto para el proyecto final (Aunque la cantidad de columnas no es demasiado grande, para el tema potabilidad del agua, las features son más que suficientes)

# %%
df2 = pd.read_csv('/content/water_potability.csv')
df2
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...
